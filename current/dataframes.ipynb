# %%
pip install pandas
# Out:
# ...
#                                               0.0/10.6 MB ? eta -:--:--
#      ------                                   1.6/10.6 MB 51.2 MB/s eta 0:00:01
#      ------                                   1.6/10.6 MB 51.2 MB/s eta 0:00:01
#      ------                                   1.6/10.6 MB 51.2 MB/s eta 0:00:01
#      ------                                   1.6/10.6 MB 51.2 MB/s eta 0:00:01
#      ------                                   1.6/10.6 MB 51.2 MB/s eta 0:00:01
#      ------                                   1.7/10.6 MB 6.0 MB/s eta 0:00:02
#      -----------                              3.1/10.6 MB 9.9 MB/s eta 0:00:01
#      -------------                            3.5/10.6 MB 10.6 MB/s eta 0:00:01
#      -------------                            3.5/10.6 MB 10.6 MB/s eta 0:00:01
#      -------------                            3.5/10.6 MB 10.6 MB/s eta 0:00:01
#      -------------                            3.5/10.6 MB 10.6 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

def paciente_Add  (nome,idade,id_paciente):
    df.loc[len(df.index)] = [nome,idade]
    
    
# Create dataset
data_list = {

    "Paciente": [],
    "Idade": []

}

# Set datafram into a variable

df = pd.DataFrame(data_list)


print('Adicionar pacientes a lista.')
print('Para parar a qualquer momento, digite PARAR.')

while True:


    userInput = input('Digite o nome do paciente: ')
    if (userInput.upper() == 'PARAR'):
        break
    else: 
        userInputAge = (input('Digite a idade do paciente: '))
        if (userInputAge.upper() == 'PARAR'):
            break
        else:
            paciente_Add(userInput,userInputAge,userInputID)
            continue 


print(df)
df.to_csv("pacientes.csv")


# Locate dataframe specific objetic accordingly to index number
# Out:
# Adicionar pacientes a lista.
# Para parar a qualquer momento, digite PARAR.
#     Paciente    Idade
# 0   Vinicius       19
# 1      Pedro       30
# 2  Rafael 40  iago 21
